# %% [markdown]
# ## National Basketball Association Most Valuable Player Machine Learning Project

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import sklearn as skl

# %%
#Import Data

df = pd.read_csv("mvp-data.csv")

#Clean up data

#TODO: Remove index, season columns, Team ID
#TODO: Remove Player Name column (?)
#TODO: Convert pos column to numeric (1-5) or remove it

#TODO: Extract award_share column (y-data), potentially assign a binary distribution (WARNING: this would require either manual input or sorting by year)

#TODO: Remove any columns not wanted for training

df
# Out:
#        season               player pos  age team_id   g  gs  mp_per_g  \
# 0        1982  Kareem Abdul-Jabbar   C   34     LAL  76  76      35.2
# 1        1982          Alvan Adams   C   27     PHO  79  75      30.3
# 2        1982         Mark Aguirre  SF   22     DAL  51  20      28.8
# 3        1982          Danny Ainge  SG   22     BOS  53   1      10.6
# 4        1982       Tiny Archibald  PG   33     BOS  68  51      31.9
# ...       ...                  ...  ..  ...     ...  ..  ..       ...
# 17692    2022       Thaddeus Young  PF   33     TOT  52   1      16.3
# 17693    2022           Trae Young  PG   23     ATL  76  76      34.9
# 17694    2022       Omer Yurtseven   C   23     MIA  56  12      12.6
# 17695    2022          Cody Zeller   C   29     POR  27   0      13.1
# 17696    2022          Ivica Zubac   C   24     LAC  76  76      24.4
#
#        fg_per_g  fga_per_g  ...    ws  ws_per_48  obpm  dbpm  bpm  vorp  \
# 0           9.9       17.1  ...  10.7      0.192   3.8   1.2  5.0   4.7
# 1           6.4       13.0  ...   7.2      0.144   1.4   2.2  3.6   3.4
# 2           7.5       16.1  ...   1.9      0.061   2.3  -1.6  0.7   1.0
# 3           1.5        4.2  ...   0.5      0.042  -3.7   1.0 -2.7  -0.1
# 4           4.5        9.6  ...   5.2      0.115   1.4  -1.3  0.1   1.1
# ...         ...        ...  ...   ...        ...   ...   ...  ...   ...
# 17692       2.7        5.2  ...   2.2      0.126   0.1   2.1  2.2   0.9
# 17693       9.4       20.3  ...  10.0      0.181   7.1  -2.0  5.2   4.8
# 17694       2.3        4.4  ...   2.1      0.145  -1.4   0.4 -1.0   0.2
# 17695       1.9        3.3  ...   1.1      0.143  -1.2  -1.0 -2.1   0.0
# 17696       4.1        6.5  ...   7.2      0.187  -0.1   0.8  0.7   1.3
#
#        award_share   mov  mov_adj  win_loss_pct
# 0            0.045  4.87     4.37         0.695
# 1            0.000  3.45     3.05         0.561
# 2            0.000 -4.43    -4.48         0.341
# 3            0.000  6.38     6.35         0.768
# 4            0.000  6.38     6.35         0.768
# ...            ...   ...      ...           ...
# 17692        0.000  0.00     0.00         0.500
# 17693        0.000  1.56     1.55         0.524
# 17694        0.000  4.45     4.23         0.646
# 17695        0.000 -8.88    -8.55         0.329
# 17696        0.000  0.02     0.09         0.512
#
# [17697 rows x 55 columns]
